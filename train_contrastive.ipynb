# %%
import numpy as np
import pandas as pd
import tensorflow as tf
import tensorflow_hub as hub
from tensorflow.keras.models import Model
from tensorflow.keras.layers import (
    Input, Embedding, Conv1D, MaxPooling1D, LSTM, Bidirectional, Dense, Dropout, BatchNormalization
    )
from tensorflow.keras.callbacks import EarlyStopping, ReduceLROnPlateau, ModelCheckpoint

from sklearn.preprocessing import LabelEncoder
from sklearn.metrics import (classification_report, confusion_matrix, 
                              accuracy_score, precision_recall_fscore_support)
from sklearn.utils.class_weight import compute_class_weight
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.model_selection import train_test_split
from gensim import downloader as api
import matplotlib.pyplot as plt
import seaborn as sns
import re
import warnings
import os
import nltk
from nltk.corpus import stopwords
from nltk.stem import WordNetLemmatizer
import tensorflow as tf
from tensorflow.keras.layers import *
from tensorflow.keras.models import Model
warnings.filterwarnings('ignore')

# %% [markdown]
# ### Preprocessing

# %%
# ============================================================
# STEP 1: LOAD TRAIN & TEST DATA
# ============================================================
df_train = pd.read_csv('data/train.csv')
df_test  = pd.read_csv('data/test.csv')

print(f"Train shape: {df_train.shape}")
print(f"Test shape:  {df_test.shape}")
# Out:
# Train shape: (82357, 6)
# Test shape:  (20590, 6)

# %%
# ============================================================
# TEST SET DEVELOPER DISTRIBUTION (TOP 250)
# ============================================================
dev_counts = df_train["assigned_to"].value_counts().head(100)

dev_counts_df = dev_counts.reset_index()
dev_counts_df.columns = ["developer", "count"]
dev_counts_df

plt.figure(figsize=(16, 6))
bars = plt.bar(dev_counts.index, dev_counts.values, color="steelblue", edgecolor="black", linewidth=0.5)
plt.title("Top 250 Developers in Test Data")
plt.xlabel("Developer")
plt.ylabel("Number of Samples")
plt.xticks(rotation=90, fontsize=6)

for bar in bars:
    height = bar.get_height()
    plt.text(
        bar.get_x() + bar.get_width() / 2,
        height + 0.5,
        f"{int(height)}",
        ha="center",
        va="bottom",
        fontsize=6,
        rotation=90,
    )

plt.tight_layout()
plt.show()

# %%
# ============================================================
# STEP 2: DEFINE FEATURES & TARGET
# ============================================================
X_train_raw = df_train['text'].astype(str).tolist()
X_test_raw  = df_test['text'].astype(str).tolist()

y_train_raw = df_train['assigned_to'].tolist()
y_test_raw  = df_test['assigned_to'].tolist()

# %%
# ============================================================
# STEP 3: TEXT PREPROCESSING
# ============================================================
nltk.download("stopwords", quiet=True)
nltk.download("wordnet", quiet=True)
nltk.download("omw-1.4", quiet=True)

stop_words = set(stopwords.words("english"))
lemmatizer = WordNetLemmatizer()

def preprocess_text(texts):
    cleaned = []
    for text in texts:
        text = text.lower()                                 # lowercase
        text = re.sub(r'http\S+|www\S+', '', text)         # remove URLs
        text = re.sub(r'[^a-zA-Z.\-\s]', '', text)         # keep letters, dot, hyphen, space
        text = re.sub(r'\s+', ' ', text).strip()           # remove extra spaces
        words = []
        for w in re.split(r'[\s.-]+', text):
            if not w:
                continue
            if len(w) > 15:
                continue
            if w in stop_words:
                continue
            words.append(lemmatizer.lemmatize(w))
        cleaned.append(' '.join(words))
    return cleaned

X_train_clean = preprocess_text(X_train_raw)
X_test_clean  = preprocess_text(X_test_raw)

print(f"\nSample cleaned text: {X_train_clean[0]}")
# Out:
# Sample cleaned text: requirement defined front fail fast insufficient package installed

# %%
# ============================================================
# STEP 3B: FILTER SHORT SAMPLES (< 5 WORDS)
# ============================================================
def filter_by_min_words(texts, labels, min_words=5):
    filtered_texts = []
    filtered_labels = []
    for text, label in zip(texts, labels):
        if len(text.split()) >= min_words:
            filtered_texts.append(text)
            filtered_labels.append(label)
    return filtered_texts, filtered_labels

X_train_clean, y_train_raw = filter_by_min_words(X_train_clean, y_train_raw, min_words=5)
X_test_clean, y_test_raw = filter_by_min_words(X_test_clean, y_test_raw, min_words=5)

print(f"Filtered train size: {len(X_train_clean)}")
print(f"Filtered test size:  {len(X_test_clean)}")
# Out:
# Filtered train size: 79410
# Filtered test size:  19827

# %%
# ============================================================
# STEP 3C: KEEP TOP-K WORDS BY TF-IDF SCORE
# ============================================================
from sklearn.feature_extraction.text import TfidfVectorizer

TOP_K_TFIDF = 50

def select_top_k_tfidf(texts, vectorizer, top_k):
    tfidf = vectorizer.transform(texts)
    feature_names = vectorizer.get_feature_names_out()
    top_texts = []
    for row_idx in range(tfidf.shape[0]):
        row = tfidf.getrow(row_idx)
        if row.nnz == 0:
            top_texts.append(texts[row_idx])
            continue
        data = row.data
        indices = row.indices
        if row.nnz > top_k:
            top_idx = data.argsort()[-top_k:]
            top_terms = {feature_names[indices[i]] for i in top_idx}
        else:
            top_terms = {feature_names[i] for i in indices}
        tokens = texts[row_idx].split()
        filtered = [t for t in tokens if t in top_terms]
        top_texts.append(" ".join(filtered) if filtered else texts[row_idx])
    return top_texts

tfidf_vectorizer = TfidfVectorizer(token_pattern=r"(?u)\b\w+\b", lowercase=False)
tfidf_vectorizer.fit(X_train_clean)

X_train_clean = select_top_k_tfidf(X_train_clean, tfidf_vectorizer, TOP_K_TFIDF)
X_test_clean = select_top_k_tfidf(X_test_clean, tfidf_vectorizer, TOP_K_TFIDF)

print(f"TF-IDF top-{TOP_K_TFIDF} sample: {X_train_clean[0]}")
# Out:
# TF-IDF top-50 sample: requirement defined front fail fast insufficient package installed

# %%
# ============================================================
# STEP 4: LABEL ENCODING
# ============================================================
label_encoder = LabelEncoder()
label_encoder.fit(y_train_raw)

y_train = label_encoder.transform(y_train_raw)
y_test  = label_encoder.transform(y_test_raw)


num_classes = len(label_encoder.classes_)
print(f"\nNumber of classes (developers): {num_classes}")

# One-hot encode for categorical crossentropy
y_train_cat = tf.keras.utils.to_categorical(y_train, num_classes)
y_test_cat  = tf.keras.utils.to_categorical(y_test,  num_classes)
# Out:
# Number of classes (developers): 100

# %% [markdown]
# ### Embedding

# %%
MAX_WORDS = 50
VEC_DIM = 100

def tokenize_texts(texts, max_words):
    tokenized = []
    for text in texts:
        tokens = text.split()
        tokenized.append(tokens[:max_words])
    return tokenized

X_train_tokens = tokenize_texts(X_train_clean, MAX_WORDS)
X_test_tokens  = tokenize_texts(X_test_clean,  MAX_WORDS)

# %%
from gensim.models import FastText

print("\nTraining FastText model...")
ft_model = FastText(
    sentences=X_train_tokens,   # list of token lists
    vector_size=VEC_DIM,         # match vec_dim
    window=5,
    min_count=1,
    sg=1,
    workers=4,
    epochs=15
)

def get_ft_embeddings(tokenized, ft_model, max_words, vec_dim):
    embeddings = np.zeros((len(tokenized), max_words, vec_dim), dtype=np.float32)
    for i, tokens in enumerate(tokenized):
        for j, token in enumerate(tokens[:max_words]):
            embeddings[i, j, :] = ft_model.wv[token]
    return embeddings

print("\nGenerating FastText embeddings for TRAIN set...")
X_train_input = get_ft_embeddings(X_train_tokens, ft_model, MAX_WORDS, VEC_DIM)

print("\nGenerating FastText embeddings for TEST set...")
X_test_input = get_ft_embeddings(X_test_tokens, ft_model, MAX_WORDS, VEC_DIM)
# Out:
# Training FastText model...
#
# Generating FastText embeddings for TRAIN set...
#
# Generating FastText embeddings for TEST set...

# %%
# Input configuration for CNN-LSTM
input_config = {
    "N": X_train_input.shape[0],
    "num_words": MAX_WORDS,
    "vec_dim": VEC_DIM,
}
input_shape = (input_config["num_words"], input_config["vec_dim"])

print(f"\nInput config: {input_config}")
# Out:
# Input config: {'N': 79410, 'num_words': 50, 'vec_dim': 100}

# %%
# ============================================================
# STEP 6: TRAIN/VAL SPLIT + BALANCED BATCH GENERATOR
# ============================================================
X_tr, X_val, y_tr, y_val, y_tr_cat, y_val_cat = train_test_split(
    X_train_input, y_train, y_train_cat,
    test_size=0.1,
    random_state=42,
    stratify=y_train,
 )

def _make_balanced_batch_indices(y, batch_size, min_pos=2, rng=None):
    if rng is None:
        rng = np.random.default_rng()
    classes = np.unique(y)
    classes_per_batch = max(1, batch_size // min_pos)
    if classes.size >= classes_per_batch:
        chosen_classes = rng.choice(classes, size=classes_per_batch, replace=False)
    else:
        chosen_classes = rng.choice(classes, size=classes_per_batch, replace=True)
    batch_indices = []
    for c in chosen_classes:
        idx = np.where(y == c)[0]
        replace = idx.size < min_pos
        batch_indices.extend(rng.choice(idx, size=min_pos, replace=replace).tolist())
    if len(batch_indices) < batch_size:
        extra = rng.choice(len(y), size=batch_size - len(batch_indices), replace=True)
        batch_indices.extend(extra.tolist())
    rng.shuffle(batch_indices)
    return np.array(batch_indices[:batch_size])

def balanced_batch_generator(X, y, batch_size, min_pos=2, one_hot=False, num_classes=None):
    rng = np.random.default_rng(42)
    while True:
        idx = _make_balanced_batch_indices(y, batch_size, min_pos=min_pos, rng=rng)
        Xb = X[idx]
        yb = y[idx]
        if one_hot:
            yb = tf.keras.utils.to_categorical(yb, num_classes)
        yield Xb, yb

# %% [markdown]
# ### Train

# %%
def build_cnn_lstm_encoder(num_words, vec_dim, proj_dim=128):
    input_shape = (num_words, vec_dim)
    inputs = Input(shape=input_shape, name="input_embeddings")

    # CNN Block — restore capacity, light L2 only
    x = Conv1D(filters=128, kernel_size=3, activation="relu",         # ↑ back to 128
               padding="same",
               kernel_regularizer=tf.keras.regularizers.l2(5e-5),     # ↓ 1e-4 → 5e-5 (softer)
               name="conv1")(inputs)
    x = BatchNormalization(name="bn1")(x)
    x = MaxPooling1D(pool_size=2, name="pool1")(x)
    x = Dropout(0.25, name="drop_cnn")(x)                             # ↓ 0.4 → 0.25

    # LSTM Block — remove recurrent_dropout, keep light input dropout
    x = LSTM(units=128,                                                # ↑ back to 128
             return_sequences=False,
             dropout=0.2,                                              # ↓ 0.3 → 0.2
             recurrent_dropout=0.0,                                    # ← removed entirely
             kernel_regularizer=tf.keras.regularizers.l2(5e-5),       # ↓ softer
             name="lstm1")(x)
    x = Dropout(0.25, name="drop_lstm")(x)                            # ↓ 0.4 → 0.25

    # Projection head for contrastive pretraining
    x = Dense(64, activation="relu",
              kernel_regularizer=tf.keras.regularizers.l2(5e-5),
              name="dense1")(x)
    proj = Dense(proj_dim, name="proj")(x)
    proj = tf.keras.layers.Lambda(
        lambda t: tf.math.l2_normalize(t, axis=1),
        name="proj_norm",
    )(proj)
    return Model(inputs=inputs, outputs=proj, name="cnn_lstm_encoder")

def supervised_contrastive_loss(temperature=0.1):
    def loss(y_true, y_pred):
        y_true = tf.reshape(tf.cast(y_true, tf.int32), [-1])
        y_pred = tf.math.l2_normalize(y_pred, axis=1)
        logits = tf.matmul(y_pred, y_pred, transpose_b=True) / temperature
        logits_mask = tf.logical_not(tf.eye(tf.shape(logits)[0], dtype=tf.bool))
        labels = tf.expand_dims(y_true, 1)
        mask_pos = tf.equal(labels, tf.transpose(labels))
        mask_pos = tf.logical_and(mask_pos, logits_mask)
        exp_logits = tf.exp(logits) * tf.cast(logits_mask, tf.float32)
        log_prob = logits - tf.math.log(tf.reduce_sum(exp_logits, axis=1, keepdims=True) + 1e-9)
        pos_log_prob = tf.reduce_sum(tf.cast(mask_pos, tf.float32) * log_prob, axis=1)
        pos_count = tf.reduce_sum(tf.cast(mask_pos, tf.float32), axis=1) + 1e-9
        mean_log_prob_pos = pos_log_prob / pos_count
        return -tf.reduce_mean(mean_log_prob_pos)
    return loss

def build_classifier_from_encoder(encoder, num_classes):
    encoder.trainable = False
    inputs = encoder.input
    x = encoder.output
    outputs = Dense(num_classes, activation="softmax", name="output")(x)
    return Model(inputs=inputs, outputs=outputs, name="cnn_lstm_supcon_classifier")

# %% [markdown]
# ### Train

# %%
encoder = build_cnn_lstm_encoder(
    num_words=input_config["num_words"],
    vec_dim=input_config["vec_dim"],
    proj_dim=128,
 )

encoder.compile(
    optimizer=tf.keras.optimizers.Adam(learning_rate=0.001),
    loss=supervised_contrastive_loss(temperature=0.1),
)

encoder.summary()
# Out:
# WARNING:tensorflow:From c:\Users\Rifat1493\miniconda3\envs\theia\lib\site-packages\keras\src\backend\tensorflow\core.py:232: The name tf.placeholder is deprecated. Please use tf.compat.v1.placeholder instead.
# Model: "cnn_lstm_encoder"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ input_embeddings (InputLayer)   │ (None, 50, 100)        │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv1 (Conv1D)                  │ (None, 50, 128)        │        38,528 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ bn1 (BatchNormalization)        │ (None, 50, 128)        │           512 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ pool1 (MaxPooling1D)            │ (None, 25, 128)        │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ drop_cnn (Dropout)              │ (None, 25, 128)        │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ lstm1 (LSTM)                    │ (None, 128)            │       131,584 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ drop_lstm (Dropout)             │ (None, 128)            │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense1 (Dense)                  │ (None, 64)             │         8,256 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ proj (Dense)                    │ (None, 128)            │         8,320 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ proj_norm (Lambda)              │ (None, 128)            │             0 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 187,200 (731.25 KB)
#  Trainable params: 186,944 (730.25 KB)
#  Non-trainable params: 256 (1.00 KB)

# %%
# ============================================================
# STEP 7: CONTRASTIVE PRETRAINING + CLASSIFIER FINE-TUNE
# ============================================================
callbacks = [
    ModelCheckpoint(
        filepath="data/best_cnn_lstm_supcon_classifier.keras",
        monitor="val_loss",
        save_best_only=True,
        save_weights_only=False,
        mode="min",
        verbose=1,
    ),
    EarlyStopping(
        monitor="val_loss",
        patience=15,
        restore_best_weights=True,
        verbose=1,
    ),
    ReduceLROnPlateau(
        monitor="val_loss",
        factor=0.5,
        patience=10,
        min_lr=1e-6,
        verbose=1,
    ),
]

print("\nContrastive pretraining (SupCon) ...")
contrastive_batch_size = 128
contrastive_gen = balanced_batch_generator(
    X_tr, y_tr, batch_size=contrastive_batch_size, min_pos=2, one_hot=False
 )
contrastive_val_gen = balanced_batch_generator(
    X_val, y_val, batch_size=contrastive_batch_size, min_pos=2, one_hot=False
 )

contrastive_steps = max(1, len(X_tr) // contrastive_batch_size)
contrastive_val_steps = max(1, len(X_val) // contrastive_batch_size)

history_contrastive = encoder.fit(
    contrastive_gen,
    validation_data=contrastive_val_gen,
    steps_per_epoch=contrastive_steps,
    validation_steps=contrastive_val_steps,
    epochs=50,
    verbose=1,
 )

print("\nTraining classifier head...")
classifier = build_classifier_from_encoder(encoder, num_classes)
classifier.compile(
    optimizer=tf.keras.optimizers.Adam(learning_rate=0.001),
    loss="categorical_crossentropy",
    metrics=["accuracy"],
)

clf_batch_size = 32
clf_gen = balanced_batch_generator(
    X_tr, y_tr, batch_size=clf_batch_size, min_pos=2, one_hot=True, num_classes=num_classes
 )
clf_val_gen = balanced_batch_generator(
    X_val, y_val, batch_size=clf_batch_size, min_pos=2, one_hot=True, num_classes=num_classes
 )

clf_steps = max(1, len(X_tr) // clf_batch_size)
clf_val_steps = max(1, len(X_val) // clf_batch_size)

history = classifier.fit(
    clf_gen,
    validation_data=clf_val_gen,
    steps_per_epoch=clf_steps,
    validation_steps=clf_val_steps,
    epochs=50,
    callbacks=callbacks,
    verbose=1,
 )

print("\nFine-tuning full model...")
encoder.trainable = True
classifier.compile(
    optimizer=tf.keras.optimizers.Adam(learning_rate=1e-4),
    loss="categorical_crossentropy",
    metrics=["accuracy"],
)

history_finetune = classifier.fit(
    clf_gen,
    validation_data=clf_val_gen,
    steps_per_epoch=clf_steps,
    validation_steps=clf_val_steps,
    epochs=50,
    callbacks=callbacks,
    verbose=1,
)
# Out:
# Contrastive pretraining (SupCon) ...
# Epoch 1/50
# 558/558 ━━━━━━━━━━━━━━━━━━━━ 23s 37ms/step - loss: 4.8126 - val_loss: 4.5847
# Epoch 2/50
# 558/558 ━━━━━━━━━━━━━━━━━━━━ 19s 35ms/step - loss: 4.4411 - val_loss: 4.2941
# Epoch 3/50
# 558/558 ━━━━━━━━━━━━━━━━━━━━ 20s 35ms/step - loss: 4.1530 - val_loss: 4.0262
# Epoch 4/50
# 558/558 ━━━━━━━━━━━━━━━━━━━━ 20s 36ms/step - loss: 3.9461 - val_loss: 3.8973
# Epoch 5/50
# 558/558 ━━━━━━━━━━━━━━━━━━━━ 20s 35ms/step - loss: 3.8192 - val_loss: 3.8063
# Epoch 6/50
# 558/558 ━━━━━━━━━━━━━━━━━━━━ 20s 36ms/step - loss: 3.6963 - val_loss: 3.7117
# Epoch 7/50
# 558/558 ━━━━━━━━━━━━━━━━━━━━ 22s 40ms/step - loss: 3.6097 - val_loss: 3.6052
# Epoch 8/50
# 558/558 ━━━━━━━━━━━━━━━━━━━━ 24s 43ms/step - loss: 3.5213 - val_loss: 3.5354
# Epoch 9/50
# 558/558 ━━━━━━━━━━━━━━━━━━━━ 22s 39ms/step - loss: 3.4594 - val_loss: 3.4550
# Epoch 10/50
# 558/558 ━━━━━━━━━━━━━━━━━━━━ 21s 38ms/step - loss: 3.3937 - val_loss: 3.4430
# Epoch 11/50
# 558/558 ━━━━━━━━━━━━━━━━━━━━ 21s 37ms/step - loss: 3.3437 - val_loss: 3.4418
# Epoch 12/50
# 558/558 ━━━━━━━━━━━━━━━━━━━━ 20s 37ms/step - loss: 3.2807 - val_loss: 3.3679
# Epoch 13/50
# 558/558 ━━━━━━━━━━━━━━━━━━━━ 20s 37ms/step - loss: 3.2456 - val_loss: 3.3512
# Epoch 14/50
# 558/558 ━━━━━━━━━━━━━━━━━━━━ 21s 37ms/step - loss: 3.2095 - val_loss: 3.2849
# Epoch 15/50
# 558/558 ━━━━━━━━━━━━━━━━━━━━ 21s 37ms/step - loss: 3.1705 - val_loss: 3.2495
# Epoch 16/50
# 558/558 ━━━━━━━━━━━━━━━━━━━━ 21s 37ms/step - loss: 3.1273 - val_loss: 3.3210
# Epoch 17/50
# 558/558 ━━━━━━━━━━━━━━━━━━━━ 21s 38ms/step - loss: 3.0895 - val_loss: 3.2798
# Epoch 18/50
# 558/558 ━━━━━━━━━━━━━━━━━━━━ 21s 37ms/step - loss: 3.0742 - val_loss: 3.1804
# Epoch 19/50
# 558/558 ━━━━━━━━━━━━━━━━━━━━ 21s 37ms/step - loss: 3.0424 - val_loss: 3.1921
# Epoch 20/50
# 558/558 ━━━━━━━━━━━━━━━━━━━━ 21s 37ms/step - loss: 3.0129 - val_loss: 3.2703
# Epoch 21/50
# 558/558 ━━━━━━━━━━━━━━━━━━━━ 21s 37ms/step - loss: 3.0040 - val_loss: 3.1855
# Epoch 22/50
# 558/558 ━━━━━━━━━━━━━━━━━━━━ 21s 38ms/step - loss: 2.9639 - val_loss: 3.1492
# Epoch 23/50
# 558/558 ━━━━━━━━━━━━━━━━━━━━ 22s 40ms/step - loss: 2.9409 - val_loss: 3.1364
# Epoch 24/50
# 558/558 ━━━━━━━━━━━━━━━━━━━━ 1404s 3s/step - loss: 2.9135 - val_loss: 3.1113
# Epoch 25/50
# 558/558 ━━━━━━━━━━━━━━━━━━━━ 20s 36ms/step - loss: 2.8877 - val_loss: 3.1160
# Epoch 26/50
# 558/558 ━━━━━━━━━━━━━━━━━━━━ 19s 35ms/step - loss: 2.8664 - val_loss: 3.1818
# Epoch 27/50
# 558/558 ━━━━━━━━━━━━━━━━━━━━ 20s 36ms/step - loss: 2.8468 - val_loss: 3.1701
# Epoch 28/50
# 558/558 ━━━━━━━━━━━━━━━━━━━━ 20s 36ms/step - loss: 2.8253 - val_loss: 3.1390
# Epoch 29/50
# 558/558 ━━━━━━━━━━━━━━━━━━━━ 20s 36ms/step - loss: 2.7946 - val_loss: 3.0845
# Epoch 30/50
# 558/558 ━━━━━━━━━━━━━━━━━━━━ 20s 36ms/step - loss: 2.7937 - val_loss: 3.0740
# Epoch 31/50
# 558/558 ━━━━━━━━━━━━━━━━━━━━ 20s 36ms/step - loss: 2.7696 - val_loss: 3.0561
# Epoch 32/50
# 558/558 ━━━━━━━━━━━━━━━━━━━━ 20s 35ms/step - loss: 2.7575 - val_loss: 3.0486
# Epoch 33/50
# 558/558 ━━━━━━━━━━━━━━━━━━━━ 20s 36ms/step - loss: 2.7226 - val_loss: 3.0666
# Epoch 34/50
# 558/558 ━━━━━━━━━━━━━━━━━━━━ 20s 36ms/step - loss: 2.7144 - val_loss: 3.0153
# Epoch 35/50
# 558/558 ━━━━━━━━━━━━━━━━━━━━ 20s 35ms/step - loss: 2.6873 - val_loss: 3.0079
# Epoch 36/50
# 558/558 ━━━━━━━━━━━━━━━━━━━━ 20s 36ms/step - loss: 2.7007 - val_loss: 2.9642
# Epoch 37/50
# 558/558 ━━━━━━━━━━━━━━━━━━━━ 20s 37ms/step - loss: 2.6609 - val_loss: 2.9694
# Epoch 38/50
# 558/558 ━━━━━━━━━━━━━━━━━━━━ 20s 36ms/step - loss: 2.6737 - val_loss: 3.0292
# Epoch 39/50
# 558/558 ━━━━━━━━━━━━━━━━━━━━ 1089s 2s/step - loss: 2.6392 - val_loss: 3.0136
# Epoch 40/50
# 558/558 ━━━━━━━━━━━━━━━━━━━━ 25s 44ms/step - loss: 2.6167 - val_loss: 2.9632
# Epoch 41/50
# 558/558 ━━━━━━━━━━━━━━━━━━━━ 25s 44ms/step - loss: 2.6043 - val_loss: 2.9990
# Epoch 42/50
# 558/558 ━━━━━━━━━━━━━━━━━━━━ 25s 44ms/step - loss: 2.6118 - val_loss: 2.9448
# Epoch 43/50
# 558/558 ━━━━━━━━━━━━━━━━━━━━ 25s 45ms/step - loss: 2.5915 - val_loss: 2.9818
# Epoch 44/50
# 558/558 ━━━━━━━━━━━━━━━━━━━━ 25s 44ms/step - loss: 2.5751 - val_loss: 2.9447
# Epoch 45/50
# 558/558 ━━━━━━━━━━━━━━━━━━━━ 24s 44ms/step - loss: 2.5526 - val_loss: 2.9977
# Epoch 46/50
# 558/558 ━━━━━━━━━━━━━━━━━━━━ 25s 44ms/step - loss: 2.5416 - val_loss: 2.9027
# Epoch 47/50
# 558/558 ━━━━━━━━━━━━━━━━━━━━ 25s 44ms/step - loss: 2.5394 - val_loss: 2.9436
# Epoch 48/50
# 558/558 ━━━━━━━━━━━━━━━━━━━━ 25s 44ms/step - loss: 2.5245 - val_loss: 2.9349
# Epoch 49/50
# 558/558 ━━━━━━━━━━━━━━━━━━━━ 25s 44ms/step - loss: 2.5030 - val_loss: 2.9069
# Epoch 50/50
# 558/558 ━━━━━━━━━━━━━━━━━━━━ 25s 44ms/step - loss: 2.5087 - val_loss: 2.9490
#
# Training classifier head...
# Epoch 1/50
# 2231/2233 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.3842 - loss: 3.6221
# Epoch 1: val_loss improved from None to 2.04369, saving model to data/best_cnn_lstm_supcon_classifier.keras
# 2233/2233 ━━━━━━━━━━━━━━━━━━━━ 25s 10ms/step - accuracy: 0.4674 - loss: 2.9059 - val_accuracy: 0.5096 - val_loss: 2.0437 - learning_rate: 0.0010
# Epoch 2/50
# 2231/2233 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.5197 - loss: 1.8540
# Epoch 2: val_loss improved from 2.04369 to 1.85216, saving model to data/best_cnn_lstm_supcon_classifier.keras
# 2233/2233 ━━━━━━━━━━━━━━━━━━━━ 23s 10ms/step - accuracy: 0.5267 - loss: 1.7642 - val_accuracy: 0.5379 - val_loss: 1.8522 - learning_rate: 0.0010
# Epoch 3/50
# 2228/2233 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.5367 - loss: 1.6242
# Epoch 3: val_loss improved from 1.85216 to 1.82029, saving model to data/best_cnn_lstm_supcon_classifier.keras
# 2233/2233 ━━━━━━━━━━━━━━━━━━━━ 23s 10ms/step - accuracy: 0.5428 - loss: 1.5943 - val_accuracy: 0.5536 - val_loss: 1.8203 - learning_rate: 0.0010
# Epoch 4/50
# 2233/2233 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.5453 - loss: 1.5669
# Epoch 4: val_loss did not improve from 1.82029
# 2233/2233 ━━━━━━━━━━━━━━━━━━━━ 23s 10ms/step - accuracy: 0.5446 - loss: 1.5595 - val_accuracy: 0.5440 - val_loss: 1.8576 - learning_rate: 0.0010
# Epoch 5/50
# 2231/2233 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.5516 - loss: 1.5393
# Epoch 5: val_loss did not improve from 1.82029
# 2233/2233 ━━━━━━━━━━━━━━━━━━━━ 23s 10ms/step - accuracy: 0.5521 - loss: 1.5332 - val_accuracy: 0.5364 - val_loss: 1.8565 - learning_rate: 0.0010
# Epoch 6/50
# 2231/2233 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.5581 - loss: 1.5176
# Epoch 6: val_loss did not improve from 1.82029
# 2233/2233 ━━━━━━━━━━━━━━━━━━━━ 23s 10ms/step - accuracy: 0.5553 - loss: 1.5190 - val_accuracy: 0.5483 - val_loss: 1.8506 - learning_rate: 0.0010
# Epoch 7/50
# 2233/2233 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.5496 - loss: 1.5425
# Epoch 7: val_loss did not improve from 1.82029
# 2233/2233 ━━━━━━━━━━━━━━━━━━━━ 23s 10ms/step - accuracy: 0.5533 - loss: 1.5284 - val_accuracy: 0.5431 - val_loss: 1.8285 - learning_rate: 0.0010
# Epoch 8/50
# 2230/2233 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.5552 - loss: 1.5135
# Epoch 8: val_loss did not improve from 1.82029
# 2233/2233 ━━━━━━━━━━━━━━━━━━━━ 24s 11ms/step - accuracy: 0.5554 - loss: 1.5157 - val_accuracy: 0.5451 - val_loss: 1.8695 - learning_rate: 0.0010
# Epoch 9/50
# 2232/2233 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.5561 - loss: 1.4998
# Epoch 9: val_loss improved from 1.82029 to 1.80296, saving model to data/best_cnn_lstm_supcon_classifier.keras
# 2233/2233 ━━━━━━━━━━━━━━━━━━━━ 24s 11ms/step - accuracy: 0.5556 - loss: 1.5093 - val_accuracy: 0.5655 - val_loss: 1.8030 - learning_rate: 0.0010
# Epoch 10/50
# 2229/2233 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.5504 - loss: 1.5260
# Epoch 10: val_loss did not improve from 1.80296
# 2233/2233 ━━━━━━━━━━━━━━━━━━━━ 24s 11ms/step - accuracy: 0.5531 - loss: 1.5158 - val_accuracy: 0.5591 - val_loss: 1.8544 - learning_rate: 0.0010
# Epoch 11/50
# 2230/2233 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.5531 - loss: 1.5161
# Epoch 11: val_loss did not improve from 1.80296
# 2233/2233 ━━━━━━━━━━━━━━━━━━━━ 21s 9ms/step - accuracy: 0.5537 - loss: 1.5143 - val_accuracy: 0.5591 - val_loss: 1.8392 - learning_rate: 0.0010
# Epoch 12/50
# 2231/2233 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.5571 - loss: 1.5216
# Epoch 12: val_loss did not improve from 1.80296
# 2233/2233 ━━━━━━━━━━━━━━━━━━━━ 19s 9ms/step - accuracy: 0.5541 - loss: 1.5239 - val_accuracy: 0.5645 - val_loss: 1.8197 - learning_rate: 0.0010
# Epoch 13/50
# 2228/2233 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.5574 - loss: 1.5090
# Epoch 13: val_loss did not improve from 1.80296
# 2233/2233 ━━━━━━━━━━━━━━━━━━━━ 19s 9ms/step - accuracy: 0.5570 - loss: 1.5042 - val_accuracy: 0.5604 - val_loss: 1.8197 - learning_rate: 0.0010
# Epoch 14/50
# 2228/2233 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.5586 - loss: 1.5076
# Epoch 14: val_loss improved from 1.80296 to 1.79830, saving model to data/best_cnn_lstm_supcon_classifier.keras
# 2233/2233 ━━━━━━━━━━━━━━━━━━━━ 23s 10ms/step - accuracy: 0.5581 - loss: 1.5072 - val_accuracy: 0.5711 - val_loss: 1.7983 - learning_rate: 0.0010
# Epoch 15/50
# 2230/2233 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.5555 - loss: 1.4967
# Epoch 15: val_loss did not improve from 1.79830
# 2233/2233 ━━━━━━━━━━━━━━━━━━━━ 27s 12ms/step - accuracy: 0.5567 - loss: 1.5018 - val_accuracy: 0.5672 - val_loss: 1.8146 - learning_rate: 0.0010
# Epoch 16/50
# 2227/2233 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.5509 - loss: 1.5119
# Epoch 16: val_loss did not improve from 1.79830
# 2233/2233 ━━━━━━━━━━━━━━━━━━━━ 22s 10ms/step - accuracy: 0.5574 - loss: 1.4996 - val_accuracy: 0.5737 - val_loss: 1.8161 - learning_rate: 0.0010
# Epoch 17/50
# 2231/2233 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.5529 - loss: 1.5213
# Epoch 17: val_loss did not improve from 1.79830
# 2233/2233 ━━━━━━━━━━━━━━━━━━━━ 20s 9ms/step - accuracy: 0.5548 - loss: 1.5125 - val_accuracy: 0.5653 - val_loss: 1.8051 - learning_rate: 0.0010
# Epoch 18/50
# 2229/2233 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.5570 - loss: 1.5203
# Epoch 18: val_loss did not improve from 1.79830
# 2233/2233 ━━━━━━━━━━━━━━━━━━━━ 20s 9ms/step - accuracy: 0.5571 - loss: 1.5060 - val_accuracy: 0.5528 - val_loss: 1.8559 - learning_rate: 0.0010
# Epoch 19/50
# 2231/2233 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.5558 - loss: 1.5118
# Epoch 19: val_loss did not improve from 1.79830
# 2233/2233 ━━━━━━━━━━━━━━━━━━━━ 21s 9ms/step - accuracy: 0.5565 - loss: 1.5066 - val_accuracy: 0.5631 - val_loss: 1.8243 - learning_rate: 0.0010
# Epoch 20/50
# 2233/2233 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.5591 - loss: 1.5046
# Epoch 20: val_loss did not improve from 1.79830
# 2233/2233 ━━━━━━━━━━━━━━━━━━━━ 21s 9ms/step - accuracy: 0.5563 - loss: 1.5117 - val_accuracy: 0.5592 - val_loss: 1.8343 - learning_rate: 0.0010
# Epoch 21/50
# 2229/2233 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.5595 - loss: 1.4904
# Epoch 21: val_loss did not improve from 1.79830
# 2233/2233 ━━━━━━━━━━━━━━━━━━━━ 19s 9ms/step - accuracy: 0.5591 - loss: 1.4938 - val_accuracy: 0.5563 - val_loss: 1.8652 - learning_rate: 0.0010
# Epoch 22/50
# 2228/2233 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.5589 - loss: 1.5014
# Epoch 22: val_loss did not improve from 1.79830
# 2233/2233 ━━━━━━━━━━━━━━━━━━━━ 20s 9ms/step - accuracy: 0.5587 - loss: 1.4969 - val_accuracy: 0.5667 - val_loss: 1.8108 - learning_rate: 0.0010
# Epoch 23/50
# 2233/2233 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.5565 - loss: 1.4905
# Epoch 23: val_loss improved from 1.79830 to 1.79034, saving model to data/best_cnn_lstm_supcon_classifier.keras
# 2233/2233 ━━━━━━━━━━━━━━━━━━━━ 20s 9ms/step - accuracy: 0.5605 - loss: 1.4901 - val_accuracy: 0.5771 - val_loss: 1.7903 - learning_rate: 0.0010
# Epoch 24/50
# 2229/2233 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.5586 - loss: 1.5040
# Epoch 24: val_loss did not improve from 1.79034
# 2233/2233 ━━━━━━━━━━━━━━━━━━━━ 19s 9ms/step - accuracy: 0.5594 - loss: 1.4997 - val_accuracy: 0.5554 - val_loss: 1.8424 - learning_rate: 0.0010
# Epoch 25/50
# 2233/2233 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.5636 - loss: 1.4817
# Epoch 25: val_loss did not improve from 1.79034
# 2233/2233 ━━━━━━━━━━━━━━━━━━━━ 19s 8ms/step - accuracy: 0.5603 - loss: 1.4918 - val_accuracy: 0.5586 - val_loss: 1.8130 - learning_rate: 0.0010
# Epoch 26/50
# 2227/2233 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.5593 - loss: 1.4998
# Epoch 26: val_loss did not improve from 1.79034
# 2233/2233 ━━━━━━━━━━━━━━━━━━━━ 19s 8ms/step - accuracy: 0.5572 - loss: 1.5094 - val_accuracy: 0.5628 - val_loss: 1.8199 - learning_rate: 0.0010
# Epoch 27/50
# 2230/2233 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.5619 - loss: 1.4932
# Epoch 27: val_loss did not improve from 1.79034
# 2233/2233 ━━━━━━━━━━━━━━━━━━━━ 19s 9ms/step - accuracy: 0.5607 - loss: 1.4923 - val_accuracy: 0.5549 - val_loss: 1.8306 - learning_rate: 0.0010
# Epoch 28/50
# 2228/2233 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.5589 - loss: 1.4965
# Epoch 28: val_loss did not improve from 1.79034
# 2233/2233 ━━━━━━━━━━━━━━━━━━━━ 20s 9ms/step - accuracy: 0.5585 - loss: 1.4988 - val_accuracy: 0.5648 - val_loss: 1.8465 - learning_rate: 0.0010
# Epoch 29/50
# 2229/2233 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.5606 - loss: 1.4971
# Epoch 29: val_loss did not improve from 1.79034
# 2233/2233 ━━━━━━━━━━━━━━━━━━━━ 19s 9ms/step - accuracy: 0.5590 - loss: 1.4978 - val_accuracy: 0.5685 - val_loss: 1.8047 - learning_rate: 0.0010
# Epoch 30/50
# 2232/2233 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.5596 - loss: 1.4919
# Epoch 30: val_loss did not improve from 1.79034
# 2233/2233 ━━━━━━━━━━━━━━━━━━━━ 20s 9ms/step - accuracy: 0.5612 - loss: 1.4914 - val_accuracy: 0.5609 - val_loss: 1.8626 - learning_rate: 0.0010
# Epoch 31/50
# 2229/2233 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.5572 - loss: 1.5015
# Epoch 31: val_loss did not improve from 1.79034
# 2233/2233 ━━━━━━━━━━━━━━━━━━━━ 21s 9ms/step - accuracy: 0.5579 - loss: 1.5029 - val_accuracy: 0.5567 - val_loss: 1.8693 - learning_rate: 0.0010
# Epoch 32/50
# 2229/2233 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.5591 - loss: 1.4960
# Epoch 32: val_loss did not improve from 1.79034
# 2233/2233 ━━━━━━━━━━━━━━━━━━━━ 23s 10ms/step - accuracy: 0.5611 - loss: 1.4934 - val_accuracy: 0.5628 - val_loss: 1.8175 - learning_rate: 0.0010
# Epoch 33/50
# 2233/2233 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.5595 - loss: 1.5044
# Epoch 33: val_loss did not improve from 1.79034
#
# Epoch 33: ReduceLROnPlateau reducing learning rate to 0.0005000000237487257.
# 2233/2233 ━━━━━━━━━━━━━━━━━━━━ 23s 10ms/step - accuracy: 0.5593 - loss: 1.5032 - val_accuracy: 0.5548 - val_loss: 1.8217 - learning_rate: 0.0010
# Epoch 34/50
# 2231/2233 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.5566 - loss: 1.5083
# Epoch 34: val_loss did not improve from 1.79034
# 2233/2233 ━━━━━━━━━━━━━━━━━━━━ 21s 9ms/step - accuracy: 0.5575 - loss: 1.5085 - val_accuracy: 0.5634 - val_loss: 1.7948 - learning_rate: 5.0000e-04
# Epoch 35/50
# 2230/2233 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.5622 - loss: 1.5009
# Epoch 35: val_loss did not improve from 1.79034
# 2233/2233 ━━━━━━━━━━━━━━━━━━━━ 20s 9ms/step - accuracy: 0.5627 - loss: 1.4932 - val_accuracy: 0.5622 - val_loss: 1.8202 - learning_rate: 5.0000e-04
# Epoch 36/50
# 2227/2233 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.5648 - loss: 1.4764
# Epoch 36: val_loss did not improve from 1.79034
# 2233/2233 ━━━━━━━━━━━━━━━━━━━━ 20s 9ms/step - accuracy: 0.5634 - loss: 1.4851 - val_accuracy: 0.5682 - val_loss: 1.8311 - learning_rate: 5.0000e-04
# Epoch 37/50
# 2230/2233 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.5561 - loss: 1.5136
# Epoch 37: val_loss did not improve from 1.79034
# 2233/2233 ━━━━━━━━━━━━━━━━━━━━ 20s 9ms/step - accuracy: 0.5570 - loss: 1.5069 - val_accuracy: 0.5720 - val_loss: 1.8169 - learning_rate: 5.0000e-04
# Epoch 38/50
# 2227/2233 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.5604 - loss: 1.5105
# Epoch 38: val_loss did not improve from 1.79034
# 2233/2233 ━━━━━━━━━━━━━━━━━━━━ 19s 9ms/step - accuracy: 0.5591 - loss: 1.5079 - val_accuracy: 0.5495 - val_loss: 1.8558 - learning_rate: 5.0000e-04
# Epoch 38: early stopping
# Restoring model weights from the end of the best epoch: 23.
#
# Fine-tuning full model...
# Epoch 1/50
# 2233/2233 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - accuracy: 0.5341 - loss: 1.7165
# Epoch 1: val_loss did not improve from 1.79034
# 2233/2233 ━━━━━━━━━━━━━━━━━━━━ 34s 14ms/step - accuracy: 0.5421 - loss: 1.6864 - val_accuracy: 0.5655 - val_loss: 1.8604 - learning_rate: 1.0000e-04
# Epoch 2/50
# 2232/2233 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - accuracy: 0.5570 - loss: 1.6365
# Epoch 2: val_loss did not improve from 1.79034
# 2233/2233 ━━━━━━━━━━━━━━━━━━━━ 32s 14ms/step - accuracy: 0.5598 - loss: 1.6296 - val_accuracy: 0.5964 - val_loss: 1.7982 - learning_rate: 1.0000e-04
# Epoch 3/50
# 2232/2233 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - accuracy: 0.5681 - loss: 1.5957
# Epoch 3: val_loss did not improve from 1.79034
# 2233/2233 ━━━━━━━━━━━━━━━━━━━━ 32s 14ms/step - accuracy: 0.5677 - loss: 1.6009 - val_accuracy: 0.6001 - val_loss: 1.7947 - learning_rate: 1.0000e-04
# Epoch 4/50
# 2231/2233 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - accuracy: 0.5763 - loss: 1.5754
# Epoch 4: val_loss did not improve from 1.79034
# 2233/2233 ━━━━━━━━━━━━━━━━━━━━ 32s 14ms/step - accuracy: 0.5761 - loss: 1.5735 - val_accuracy: 0.5820 - val_loss: 1.8664 - learning_rate: 1.0000e-04
# Epoch 5/50
# 2233/2233 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - accuracy: 0.5827 - loss: 1.5576
# Epoch 5: val_loss did not improve from 1.79034
# 2233/2233 ━━━━━━━━━━━━━━━━━━━━ 32s 14ms/step - accuracy: 0.5839 - loss: 1.5571 - val_accuracy: 0.5929 - val_loss: 1.8346 - learning_rate: 1.0000e-04
# Epoch 6/50
# 2230/2233 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - accuracy: 0.5917 - loss: 1.5185
# Epoch 6: val_loss did not improve from 1.79034
# 2233/2233 ━━━━━━━━━━━━━━━━━━━━ 32s 14ms/step - accuracy: 0.5910 - loss: 1.5220 - val_accuracy: 0.5987 - val_loss: 1.8258 - learning_rate: 1.0000e-04
# Epoch 7/50
# 2231/2233 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - accuracy: 0.5932 - loss: 1.5222
# Epoch 7: val_loss improved from 1.79034 to 1.74137, saving model to data/best_cnn_lstm_supcon_classifier.keras
# 2233/2233 ━━━━━━━━━━━━━━━━━━━━ 32s 14ms/step - accuracy: 0.5947 - loss: 1.5191 - val_accuracy: 0.6138 - val_loss: 1.7414 - learning_rate: 1.0000e-04
# Epoch 8/50
# 2230/2233 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - accuracy: 0.5992 - loss: 1.5097
# Epoch 8: val_loss did not improve from 1.74137
# 2233/2233 ━━━━━━━━━━━━━━━━━━━━ 32s 14ms/step - accuracy: 0.5999 - loss: 1.5041 - val_accuracy: 0.5968 - val_loss: 1.8164 - learning_rate: 1.0000e-04
# Epoch 9/50
# 2233/2233 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - accuracy: 0.6014 - loss: 1.4973
# Epoch 9: val_loss did not improve from 1.74137
# 2233/2233 ━━━━━━━━━━━━━━━━━━━━ 33s 15ms/step - accuracy: 0.6015 - loss: 1.4996 - val_accuracy: 0.6134 - val_loss: 1.7827 - learning_rate: 1.0000e-04
# Epoch 10/50
# 2233/2233 ━━━━━━━━━━━━━━━━━━━━ 0s 11s/step - accuracy: 0.6052 - loss: 1.4886
# Epoch 10: val_loss did not improve from 1.74137
# 2233/2233 ━━━━━━━━━━━━━━━━━━━━ 25042s 11s/step - accuracy: 0.6059 - loss: 1.4857 - val_accuracy: 0.6116 - val_loss: 1.7945 - learning_rate: 1.0000e-04
# Epoch 11/50
# 2232/2233 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - accuracy: 0.6106 - loss: 1.4645
# Epoch 11: val_loss improved from 1.74137 to 1.73880, saving model to data/best_cnn_lstm_supcon_classifier.keras
# 2233/2233 ━━━━━━━━━━━━━━━━━━━━ 44s 20ms/step - accuracy: 0.6125 - loss: 1.4571 - val_accuracy: 0.6227 - val_loss: 1.7388 - learning_rate: 1.0000e-04
# Epoch 12/50
# 2233/2233 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - accuracy: 0.6100 - loss: 1.4600
# Epoch 12: val_loss did not improve from 1.73880
# 2233/2233 ━━━━━━━━━━━━━━━━━━━━ 38s 17ms/step - accuracy: 0.6137 - loss: 1.4554 - val_accuracy: 0.6207 - val_loss: 1.7967 - learning_rate: 1.0000e-04
# Epoch 13/50
# 2233/2233 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - accuracy: 0.6164 - loss: 1.4477
# Epoch 13: val_loss did not improve from 1.73880
# 2233/2233 ━━━━━━━━━━━━━━━━━━━━ 37s 16ms/step - accuracy: 0.6176 - loss: 1.4433 - val_accuracy: 0.6153 - val_loss: 1.7992 - learning_rate: 1.0000e-04
# Epoch 14/50
# 2233/2233 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - accuracy: 0.6187 - loss: 1.4421
# Epoch 14: val_loss did not improve from 1.73880
# 2233/2233 ━━━━━━━━━━━━━━━━━━━━ 33s 15ms/step - accuracy: 0.6211 - loss: 1.4373 - val_accuracy: 0.6285 - val_loss: 1.7814 - learning_rate: 1.0000e-04
# Epoch 15/50
# 2230/2233 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - accuracy: 0.6234 - loss: 1.4298
# Epoch 15: val_loss did not improve from 1.73880
# 2233/2233 ━━━━━━━━━━━━━━━━━━━━ 37s 17ms/step - accuracy: 0.6257 - loss: 1.4228 - val_accuracy: 0.6218 - val_loss: 1.7751 - learning_rate: 1.0000e-04
# Epoch 16/50
# 2233/2233 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - accuracy: 0.6288 - loss: 1.4124
# Epoch 16: val_loss improved from 1.73880 to 1.72303, saving model to data/best_cnn_lstm_supcon_classifier.keras
# 2233/2233 ━━━━━━━━━━━━━━━━━━━━ 38s 17ms/step - accuracy: 0.6283 - loss: 1.4199 - val_accuracy: 0.6381 - val_loss: 1.7230 - learning_rate: 1.0000e-04
# Epoch 17/50
# 2231/2233 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - accuracy: 0.6282 - loss: 1.4201
# Epoch 17: val_loss did not improve from 1.72303
# 2233/2233 ━━━━━━━━━━━━━━━━━━━━ 37s 17ms/step - accuracy: 0.6311 - loss: 1.4117 - val_accuracy: 0.6373 - val_loss: 1.7325 - learning_rate: 1.0000e-04
# Epoch 18/50
# 2232/2233 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - accuracy: 0.6305 - loss: 1.4076
# Epoch 18: val_loss did not improve from 1.72303
# 2233/2233 ━━━━━━━━━━━━━━━━━━━━ 37s 17ms/step - accuracy: 0.6320 - loss: 1.4039 - val_accuracy: 0.6333 - val_loss: 1.7820 - learning_rate: 1.0000e-04
# Epoch 19/50
# 2233/2233 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - accuracy: 0.6326 - loss: 1.4040
# Epoch 19: val_loss did not improve from 1.72303
# 2233/2233 ━━━━━━━━━━━━━━━━━━━━ 38s 17ms/step - accuracy: 0.6353 - loss: 1.3954 - val_accuracy: 0.6368 - val_loss: 1.8068 - learning_rate: 1.0000e-04
# Epoch 20/50
# 2231/2233 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - accuracy: 0.6394 - loss: 1.3815
# Epoch 20: val_loss did not improve from 1.72303
# 2233/2233 ━━━━━━━━━━━━━━━━━━━━ 38s 17ms/step - accuracy: 0.6408 - loss: 1.3792 - val_accuracy: 0.6405 - val_loss: 1.7678 - learning_rate: 1.0000e-04
# Epoch 21/50
# 2232/2233 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - accuracy: 0.6367 - loss: 1.4009
# Epoch 21: val_loss did not improve from 1.72303
# 2233/2233 ━━━━━━━━━━━━━━━━━━━━ 39s 17ms/step - accuracy: 0.6391 - loss: 1.3903 - val_accuracy: 0.6436 - val_loss: 1.7298 - learning_rate: 1.0000e-04
# Epoch 22/50
# 2231/2233 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - accuracy: 0.6453 - loss: 1.3533
# Epoch 22: val_loss improved from 1.72303 to 1.67807, saving model to data/best_cnn_lstm_supcon_classifier.keras
# 2233/2233 ━━━━━━━━━━━━━━━━━━━━ 38s 17ms/step - accuracy: 0.6451 - loss: 1.3588 - val_accuracy: 0.6589 - val_loss: 1.6781 - learning_rate: 1.0000e-04
# Epoch 23/50
# 2233/2233 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - accuracy: 0.6403 - loss: 1.3780
# Epoch 23: val_loss did not improve from 1.67807
# 2233/2233 ━━━━━━━━━━━━━━━━━━━━ 37s 17ms/step - accuracy: 0.6423 - loss: 1.3732 - val_accuracy: 0.6527 - val_loss: 1.6860 - learning_rate: 1.0000e-04
# Epoch 24/50
# 2232/2233 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - accuracy: 0.6472 - loss: 1.3570
# Epoch 24: val_loss did not improve from 1.67807
# 2233/2233 ━━━━━━━━━━━━━━━━━━━━ 38s 17ms/step - accuracy: 0.6483 - loss: 1.3533 - val_accuracy: 0.6463 - val_loss: 1.7377 - learning_rate: 1.0000e-04
# Epoch 25/50
# 2230/2233 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - accuracy: 0.6546 - loss: 1.3384
# Epoch 25: val_loss did not improve from 1.67807
# 2233/2233 ━━━━━━━━━━━━━━━━━━━━ 37s 17ms/step - accuracy: 0.6543 - loss: 1.3396 - val_accuracy: 0.6578 - val_loss: 1.6920 - learning_rate: 1.0000e-04
# Epoch 26/50
# 2233/2233 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - accuracy: 0.6496 - loss: 1.3585
# Epoch 26: val_loss did not improve from 1.67807
# 2233/2233 ━━━━━━━━━━━━━━━━━━━━ 38s 17ms/step - accuracy: 0.6519 - loss: 1.3485 - val_accuracy: 0.6537 - val_loss: 1.6955 - learning_rate: 1.0000e-04
# Epoch 27/50
# 2230/2233 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - accuracy: 0.6548 - loss: 1.3362
# Epoch 27: val_loss did not improve from 1.67807
# 2233/2233 ━━━━━━━━━━━━━━━━━━━━ 38s 17ms/step - accuracy: 0.6541 - loss: 1.3342 - val_accuracy: 0.6654 - val_loss: 1.6833 - learning_rate: 1.0000e-04
# Epoch 28/50
# 2231/2233 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - accuracy: 0.6604 - loss: 1.3282
# Epoch 28: val_loss did not improve from 1.67807
# 2233/2233 ━━━━━━━━━━━━━━━━━━━━ 38s 17ms/step - accuracy: 0.6597 - loss: 1.3318 - val_accuracy: 0.6510 - val_loss: 1.7676 - learning_rate: 1.0000e-04
# Epoch 29/50
# 2233/2233 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - accuracy: 0.6575 - loss: 1.3290
# Epoch 29: val_loss did not improve from 1.67807
# 2233/2233 ━━━━━━━━━━━━━━━━━━━━ 38s 17ms/step - accuracy: 0.6579 - loss: 1.3326 - val_accuracy: 0.6626 - val_loss: 1.7125 - learning_rate: 1.0000e-04
# Epoch 30/50
# 2231/2233 ━━━━━━━━━━━━━━━━━━━━ 0s 56ms/step - accuracy: 0.6597 - loss: 1.3257
# Epoch 30: val_loss did not improve from 1.67807
# 2233/2233 ━━━━━━━━━━━━━━━━━━━━ 127s 57ms/step - accuracy: 0.6605 - loss: 1.3232 - val_accuracy: 0.6555 - val_loss: 1.7313 - learning_rate: 1.0000e-04
# Epoch 31/50
# 2232/2233 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - accuracy: 0.6686 - loss: 1.2942
# Epoch 31: val_loss improved from 1.67807 to 1.65718, saving model to data/best_cnn_lstm_supcon_classifier.keras
# 2233/2233 ━━━━━━━━━━━━━━━━━━━━ 40s 18ms/step - accuracy: 0.6653 - loss: 1.3071 - val_accuracy: 0.6735 - val_loss: 1.6572 - learning_rate: 1.0000e-04
# Epoch 32/50
# 2230/2233 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - accuracy: 0.6636 - loss: 1.3105
# Epoch 32: val_loss did not improve from 1.65718
# 2233/2233 ━━━━━━━━━━━━━━━━━━━━ 38s 17ms/step - accuracy: 0.6668 - loss: 1.3061 - val_accuracy: 0.6528 - val_loss: 1.7345 - learning_rate: 1.0000e-04
# Epoch 33/50
# 2232/2233 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - accuracy: 0.6674 - loss: 1.3008
# Epoch 33: val_loss did not improve from 1.65718
# 2233/2233 ━━━━━━━━━━━━━━━━━━━━ 33s 15ms/step - accuracy: 0.6679 - loss: 1.2988 - val_accuracy: 0.6712 - val_loss: 1.6962 - learning_rate: 1.0000e-04
# Epoch 34/50
# 2233/2233 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 0.6692 - loss: 1.2985
# Epoch 34: val_loss did not improve from 1.65718
# 2233/2233 ━━━━━━━━━━━━━━━━━━━━ 35s 16ms/step - accuracy: 0.6696 - loss: 1.2964 - val_accuracy: 0.6604 - val_loss: 1.6803 - learning_rate: 1.0000e-04
# Epoch 35/50
# 2232/2233 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - accuracy: 0.6685 - loss: 1.2936
# Epoch 35: val_loss did not improve from 1.65718
# 2233/2233 ━━━━━━━━━━━━━━━━━━━━ 39s 17ms/step - accuracy: 0.6695 - loss: 1.2884 - val_accuracy: 0.6673 - val_loss: 1.6620 - learning_rate: 1.0000e-04
# Epoch 36/50
# 2232/2233 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - accuracy: 0.6759 - loss: 1.2825
# Epoch 36: val_loss improved from 1.65718 to 1.62494, saving model to data/best_cnn_lstm_supcon_classifier.keras
# 2233/2233 ━━━━━━━━━━━━━━━━━━━━ 39s 17ms/step - accuracy: 0.6747 - loss: 1.2797 - val_accuracy: 0.6808 - val_loss: 1.6249 - learning_rate: 1.0000e-04
# Epoch 37/50
# 2233/2233 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - accuracy: 0.6724 - loss: 1.2806
# Epoch 37: val_loss did not improve from 1.62494
# 2233/2233 ━━━━━━━━━━━━━━━━━━━━ 38s 17ms/step - accuracy: 0.6722 - loss: 1.2838 - val_accuracy: 0.6779 - val_loss: 1.6488 - learning_rate: 1.0000e-04
# Epoch 38/50
# 2231/2233 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - accuracy: 0.6798 - loss: 1.2589
# Epoch 38: val_loss did not improve from 1.62494
# 2233/2233 ━━━━━━━━━━━━━━━━━━━━ 38s 17ms/step - accuracy: 0.6788 - loss: 1.2652 - val_accuracy: 0.6686 - val_loss: 1.6711 - learning_rate: 1.0000e-04
# Epoch 39/50
# 2231/2233 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - accuracy: 0.6757 - loss: 1.2743
# Epoch 39: val_loss did not improve from 1.62494
# 2233/2233 ━━━━━━━━━━━━━━━━━━━━ 39s 17ms/step - accuracy: 0.6781 - loss: 1.2655 - val_accuracy: 0.6689 - val_loss: 1.6982 - learning_rate: 1.0000e-04
# Epoch 40/50
# 2233/2233 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - accuracy: 0.6785 - loss: 1.2709
# Epoch 40: val_loss did not improve from 1.62494
# 2233/2233 ━━━━━━━━━━━━━━━━━━━━ 39s 17ms/step - accuracy: 0.6799 - loss: 1.2679 - val_accuracy: 0.6759 - val_loss: 1.6586 - learning_rate: 1.0000e-04
# Epoch 41/50
# 2231/2233 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - accuracy: 0.6797 - loss: 1.2673
# Epoch 41: val_loss did not improve from 1.62494
# 2233/2233 ━━━━━━━━━━━━━━━━━━━━ 39s 17ms/step - accuracy: 0.6793 - loss: 1.2675 - val_accuracy: 0.6749 - val_loss: 1.6278 - learning_rate: 1.0000e-04
# Epoch 42/50
# 2231/2233 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - accuracy: 0.6805 - loss: 1.2617
# Epoch 42: val_loss improved from 1.62494 to 1.56832, saving model to data/best_cnn_lstm_supcon_classifier.keras
# 2233/2233 ━━━━━━━━━━━━━━━━━━━━ 39s 17ms/step - accuracy: 0.6835 - loss: 1.2522 - val_accuracy: 0.6930 - val_loss: 1.5683 - learning_rate: 1.0000e-04
# Epoch 43/50
# 2232/2233 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - accuracy: 0.6850 - loss: 1.2482
# Epoch 43: val_loss did not improve from 1.56832
# 2233/2233 ━━━━━━━━━━━━━━━━━━━━ 41s 18ms/step - accuracy: 0.6859 - loss: 1.2453 - val_accuracy: 0.6759 - val_loss: 1.6562 - learning_rate: 1.0000e-04
# Epoch 44/50
# 2232/2233 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - accuracy: 0.6857 - loss: 1.2433
# Epoch 44: val_loss did not improve from 1.56832
# 2233/2233 ━━━━━━━━━━━━━━━━━━━━ 38s 17ms/step - accuracy: 0.6870 - loss: 1.2384 - val_accuracy: 0.6680 - val_loss: 1.6395 - learning_rate: 1.0000e-04
# Epoch 45/50
# 2233/2233 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - accuracy: 0.6874 - loss: 1.2390
# Epoch 45: val_loss did not improve from 1.56832
# 2233/2233 ━━━━━━━━━━━━━━━━━━━━ 46s 20ms/step - accuracy: 0.6880 - loss: 1.2374 - val_accuracy: 0.6725 - val_loss: 1.6547 - learning_rate: 1.0000e-04
# Epoch 46/50
# 2231/2233 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - accuracy: 0.6872 - loss: 1.2457
# Epoch 46: val_loss did not improve from 1.56832
# 2233/2233 ━━━━━━━━━━━━━━━━━━━━ 43s 19ms/step - accuracy: 0.6867 - loss: 1.2454 - val_accuracy: 0.6811 - val_loss: 1.6650 - learning_rate: 1.0000e-04
# Epoch 47/50
# 2232/2233 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - accuracy: 0.6916 - loss: 1.2184
# Epoch 47: val_loss did not improve from 1.56832
# 2233/2233 ━━━━━━━━━━━━━━━━━━━━ 39s 17ms/step - accuracy: 0.6901 - loss: 1.2272 - val_accuracy: 0.6726 - val_loss: 1.6981 - learning_rate: 1.0000e-04
# Epoch 48/50
# 2231/2233 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - accuracy: 0.6917 - loss: 1.2248
# Epoch 48: val_loss did not improve from 1.56832
# 2233/2233 ━━━━━━━━━━━━━━━━━━━━ 39s 17ms/step - accuracy: 0.6909 - loss: 1.2288 - val_accuracy: 0.6837 - val_loss: 1.6371 - learning_rate: 1.0000e-04
# Epoch 49/50
# 2231/2233 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - accuracy: 0.6897 - loss: 1.2247
# Epoch 49: val_loss did not improve from 1.56832
# 2233/2233 ━━━━━━━━━━━━━━━━━━━━ 39s 18ms/step - accuracy: 0.6884 - loss: 1.2268 - val_accuracy: 0.6821 - val_loss: 1.6489 - learning_rate: 1.0000e-04
# Epoch 50/50
# 2231/2233 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - accuracy: 0.6938 - loss: 1.2153
# Epoch 50: val_loss did not improve from 1.56832
# 2233/2233 ━━━━━━━━━━━━━━━━━━━━ 33s 15ms/step - accuracy: 0.6930 - loss: 1.2226 - val_accuracy: 0.6780 - val_loss: 1.6883 - learning_rate: 1.0000e-04
# Restoring model weights from the end of the best epoch: 42.

# %%
plt.figure(figsize=(7, 4))
plt.plot(history.history['loss'], label='Train Loss', linewidth=2)
plt.plot(history.history['val_loss'], label='Val Loss', linewidth=2)
plt.title('Loss per Epoch')
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.legend()
plt.grid(True, alpha=0.3)
plt.show()

# %% [markdown]
# ### Testing

# %%
# ============================================================
# LOAD BEST MODEL FOR EVALUATION
# ============================================================
# print("\nLoading best saved model for evaluation...")
# classifier = tf.keras.models.load_model(
#     "data/best_cnn_lstm_supcon_classifier.keras",
#     custom_objects={"loss": supervised_contrastive_loss(temperature=0.1)},
#  )
# print("Best model loaded successfully!")

# %%
# ============================================================
# STEP 8: EVALUATE ON TEST SET
# ============================================================
print("\nEvaluating on Test Set...")
y_pred_prob = classifier.predict(X_test_input, batch_size=32)
y_pred      = np.argmax(y_pred_prob, axis=1)

# Decode labels
y_test_labels = label_encoder.inverse_transform(y_test)
y_pred_labels = label_encoder.inverse_transform(y_pred)

# Overall metrics
accuracy  = accuracy_score(y_test, y_pred)
precision, recall, f1, _ = precision_recall_fscore_support(
    y_test, y_pred, average="weighted"
 )

print(f"\n{'='*50}")
print(f"  Accuracy  : {accuracy*100:.2f}%")
print(f"  Precision : {precision*100:.2f}%")
print(f"  Recall    : {recall*100:.2f}%")
print(f"  F1-Score  : {f1*100:.2f}%")
print(f"{'='*50}")
# Out:
# Evaluating on Test Set...
# 620/620 ━━━━━━━━━━━━━━━━━━━━ 4s 6ms/step
#
# ==================================================
#   Accuracy  : 68.65%
#   Precision : 69.27%
#   Recall    : 68.65%
#   F1-Score  : 65.37%
# ==================================================

# %%
# import shap

# np.random.seed(42)

# # ✅ Drastically reduced sample sizes
# SHAP_SAMPLE_SIZE = 20       # was 50 — biggest time saver
# SHAP_BACKGROUND_SIZE = 10   # was 25

# sample_size = min(SHAP_SAMPLE_SIZE, len(X_test_input))
# background_size = min(SHAP_BACKGROUND_SIZE, len(X_train_input))
# sample_idx = np.random.choice(len(X_test_input), size=sample_size, replace=False)
# background_idx = np.random.choice(len(X_train_input), size=background_size, replace=False)

# X_sample = X_test_input[sample_idx]
# X_background = X_train_input[background_idx]

# # ✅ batch_size limits how many samples are processed per forward pass
# explainer = shap.GradientExplainer(classifier, X_background)
# shap_values = explainer.shap_values(X_sample)  # was unbatched

# # ✅ Vectorized aggregation — avoids slow Python loops over samples/tokens
# shap_stack = np.stack([np.abs(sv) for sv in shap_values], axis=0)
# shap_abs = shap_stack.mean(axis=0)  # (n_samples, max_words, vec_dim)

# # ✅ Collapse embedding dim once upfront instead of inside the loop
# token_importance = shap_abs.mean(axis=-1)  # (n_samples, max_words)

# token_scores = {}
# for i, idx in enumerate(sample_idx):
#     tokens = X_test_tokens[idx]
#     scores = token_importance[i, :len(tokens)]   # ✅ slice once, no per-token mean()
#     for j, token in enumerate(tokens[:shap_abs.shape[1]]):
#         token_scores[token] = token_scores.get(token, 0.0) + float(scores[j])

# top_5 = sorted(token_scores.items(), key=lambda x: x[1], reverse=True)[:5]
# print("\nTop 5 tokens by mean |SHAP|:")
# for token, score in top_5:
#     print(f"  {token}: {score:.6f}")

# %% [markdown]
# ### Visualisation

# %%
# ============================================================
# STEP 9: VISUALIZATION CHARTS
# ============================================================
# Chart 1: Training History - Accuracy
plt.figure(figsize=(8, 5))
plt.plot(history.history['accuracy'], label='Train Accuracy', color='steelblue', linewidth=2)
plt.plot(history.history['val_accuracy'], label='Val Accuracy', color='darkorange', linewidth=2)
plt.title('Model Accuracy Over Epochs', fontweight='bold')
plt.xlabel('Epoch')
plt.ylabel('Accuracy')
plt.legend()
plt.grid(True, alpha=0.3)
plt.tight_layout()
# plt.savefig('cnn_lstm_accuracy.png', dpi=150, bbox_inches='tight')
plt.show()

# Chart 2: Training History - Loss
plt.figure(figsize=(8, 5))
plt.plot(history.history['loss'], label='Train Loss', color='steelblue', linewidth=2)
plt.plot(history.history['val_loss'], label='Val Loss', color='darkorange', linewidth=2)
plt.title('Model Loss Over Epochs', fontweight='bold')
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.legend()
plt.grid(True, alpha=0.3)
plt.tight_layout()
# plt.savefig('cnn_lstm_loss.png', dpi=150, bbox_inches='tight')
plt.show()

# Chart 3: Overall Metrics Bar Chart
metrics = ['Accuracy', 'Precision', 'Recall', 'F1-Score']
values = [accuracy, precision, recall, f1]
colors = ['#2196F3', '#4CAF50', '#FF9800', '#E91E63']

plt.figure(figsize=(8, 5))
bars = plt.bar(metrics, values, color=colors, edgecolor='black', linewidth=0.8)
plt.title('Overall Performance Metrics', fontweight='bold')
plt.ylabel('Score')
plt.ylim(0, 1.1)
plt.grid(True, axis='y', alpha=0.3)
for bar, val in zip(bars, values):
    plt.text(bar.get_x() + bar.get_width() / 2, bar.get_height() + 0.02,
             f'{val*100:.2f}%', ha='center', va='bottom', fontweight='bold')
plt.tight_layout()
# plt.savefig('cnn_lstm_overall_metrics.png', dpi=150, bbox_inches='tight')
plt.show()

# Chart 4: Per-Class Precision Recall F1 (Top 20 developers)
report_dict = classification_report(
    y_test_labels, y_pred_labels, output_dict=True, zero_division=0
)
report_df = pd.DataFrame(report_dict).T
report_df = report_df.drop(['accuracy', 'macro avg', 'weighted avg'], errors='ignore')
report_df = report_df[['precision', 'recall', 'f1-score']].astype(float)
report_df = report_df.sort_values('f1-score', ascending=False).head(20)

x = np.arange(len(report_df))
width = 0.25

plt.figure(figsize=(10, 6))
plt.bar(x - width, report_df['precision'], width, label='Precision', color='#2196F3', alpha=0.85)
plt.bar(x, report_df['recall'], width, label='Recall', color='#4CAF50', alpha=0.85)
plt.bar(x + width, report_df['f1-score'], width, label='F1-Score', color='#E91E63', alpha=0.85)
plt.title('Per-Developer Metrics (Top 20 by F1)', fontweight='bold')
plt.xticks(x, report_df.index, rotation=90, fontsize=7)
plt.ylabel('Score')
plt.ylim(0, 1.1)
plt.legend()
plt.grid(True, axis='y', alpha=0.3)
plt.tight_layout()
# plt.savefig('cnn_lstm_per_developer_metrics.png', dpi=150, bbox_inches='tight')
plt.show()

# Chart 5: Confusion Matrix (Top 15 developers)
top_15_devs = report_df.head(15).index.tolist()
mask_test = pd.Series(y_test_labels).isin(top_15_devs)
y_test_top15 = np.array(y_test_labels)[mask_test]
y_pred_top15 = np.array(y_pred_labels)[mask_test]

cm = confusion_matrix(y_test_top15, y_pred_top15, labels=top_15_devs)
plt.figure(figsize=(9, 7))
sns.heatmap(
    cm, annot=True, fmt='d', cmap='Blues',
    xticklabels=top_15_devs, yticklabels=top_15_devs,
    linewidths=0.5
 )
plt.title('Confusion Matrix (Top 15 Developers)', fontweight='bold')
plt.xlabel('Predicted')
plt.ylabel('Actual')
plt.xticks(rotation=90, fontsize=7)
plt.yticks(rotation=0, fontsize=7)
plt.tight_layout()
# plt.savefig('cnn_lstm_confusion_matrix_top15.png', dpi=150, bbox_inches='tight')
plt.show()

# Chart 6: F1 Score Distribution
plt.figure(figsize=(8, 5))
plt.hist(report_df['f1-score'], bins=20, color='#9C27B0', edgecolor='black', alpha=0.8)
plt.axvline(
    report_df['f1-score'].mean(), color='red', linestyle='--', linewidth=2,
    label=f"Mean F1: {report_df['f1-score'].mean():.2f}"
)
plt.title('F1-Score Distribution Across Developers', fontweight='bold')
plt.xlabel('F1-Score')
plt.ylabel('Number of Developers')
plt.legend()
plt.grid(True, alpha=0.3)
plt.tight_layout()
# plt.savefig('cnn_lstm_f1_distribution.png', dpi=150, bbox_inches='tight')
plt.show()

print("\nCharts saved as individual PNG files.")
# Out:
# Charts saved as individual PNG files.
